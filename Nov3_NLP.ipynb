# %% [markdown]
# <a href="https://colab.research.google.com/github/Athulya2528/Athulya2528/blob/main/Nov3_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #TASK 1
#
# Read the sentences and label them manually as: Positive / Negative / Neutral

# %%
#process 1
import pandas as pd

data = {
    "text": [
        "I love cbs",
        "This subject is difficult",
        "I am happy today",
        "I hate homework",
        "The weather is okay"
    ]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# I love Cbs - Positive
# This Subject Difficult - Negative
# I am happy today - positive
# i hate homework - negative
# The

# %%
#Process 2
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

df['score'] = df['text'].apply(lambda x: sia.polarity_scores(x)['compound'])
df['sentiment'] = df['score'].apply(lambda x:
                                    'Positive' if x > 0
                                    else ('Negative' if x < 0
                                    else 'Neutral'))
df
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                         text   score sentiment
# 0                 I love cbs  0.6369  Positive
# 1  This subject is difficult -0.3612  Negative
# 2           I am happy today  0.5719  Positive
# 3            I hate homework -0.5719  Negative
# 4        The weather is okay  0.2263  Positive

# %% [markdown]
# Change the sentences in process 2

# %%
#process 3
#!pip install afinn
from afinn import Afinn

af = Afinn()

sentences = ["I love this class", "I hate homework", "This is okay"]
for s in sentences:
    print(s, af.score(s))
# Out:
# Requirement already satisfied: afinn in /usr/local/lib/python3.12/dist-packages (0.1)
# I love this class 3.0
# I hate homework -3.0
# This is okay 0.0

# %%
#process 4
#!pip install textblob
from textblob import TextBlob

sentences = ["I love this class", "I hate homework", "This is okay"]
for s in sentences:
    blob = TextBlob(s)
    print(s, blob.sentiment)
# Out:
# I love this class Sentiment(polarity=0.5, subjectivity=0.6)
# I hate homework Sentiment(polarity=-0.8, subjectivity=0.9)
# This is okay Sentiment(polarity=0.5, subjectivity=0.5)

# %% [markdown]
# how VADER differs form Affin and TextBlob?

# %%
#Let us compare !
from textblob import TextBlob

df['textblob_score'] = df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['textblob_sentiment'] = df['textblob_score'].apply(
    lambda x: 'Positive' if x>0 else ('Negative' if x<0 else 'Neutral')
)
df

# %% [markdown]
# Write two sarcastic sentences like
# Oh great, another assignment 😒
# 👉 Test sentiment in VADER & TextBlob
# 👉 Discuss: Can computers detect sarcasm?

# %% [markdown]
# #TASK 2

# %%
### TASK 2

texts = [
    "I LOVE this movie!!! 😍😍",
    "This course is SO boring... 😴 ",
    "I think AI is amazing 🤖💡",
    "Not sure if I like this. 🤷",
    "Great work!!! Keep it up 🔥🔥"
]

# %% [markdown]
# Put it in dataframe

# %%
#import pandas as pd
#df = pd.DataFrame(texts, columns=["text"])
#df

# %%
df['clean_text'] = df['text'].str.lower()
df['clean_text'] = df['clean_text'].str.strip()
df[['text','clean_text']]

# %% [markdown]
# Why do we convert text to lowercase?

# %%
import string
df['no_punct'] = df['clean_text'].str.translate(str.maketrans('', '', string.punctuation))
df[['clean_text','no_punct']]

# %% [markdown]
# What happens to meaning if punctuation is removed?

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop = set(stopwords.words('english'))
df['no_stopwords'] = df['no_punct'].apply(lambda x: " ".join([word for word in x.split() if word not in stop]))
df[['no_punct','no_stopwords']]

# %% [markdown]
# Why remove stopwords?

# %%
import re

def remove_emojis(text):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"
                           u"\U0001F300-\U0001F5FF"
                           u"\U0001F680-\U0001F6FF"
                           u"\U0001F1E0-\U0001F1FF"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

df['no_emoji'] = df['no_stopwords'].apply(remove_emojis)
df[['no_stopwords','no_emoji']]

# %% [markdown]
# Can emojis express emotion? Give an example.
